# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# %%
documents = ['cats say meow', 'dogs say woof', 'dogs chase cats']

# %%
model = TfidfVectorizer()

# %%
k = model.fit(documents)

# %%
k.idf_
# Out:
# array([1.28768207, 1.69314718, 1.28768207, 1.69314718, 1.28768207,
#        1.69314718])

# %%
k.vocabulary_
# Out:
# {'cats': 0, 'say': 4, 'meow': 3, 'dogs': 2, 'woof': 5, 'chase': 1}

# %%
matrix = model.fit_transform(documents)

# %%
matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 9 stored elements and shape (3, 6)>

# %%
matrix.toarray()
# Out:
# array([[0.51785612, 0.        , 0.        , 0.68091856, 0.51785612,
#         0.        ],
#        [0.        , 0.        , 0.51785612, 0.        , 0.51785612,
#         0.68091856],
#        [0.51785612, 0.68091856, 0.51785612, 0.        , 0.        ,
#         0.        ]])
