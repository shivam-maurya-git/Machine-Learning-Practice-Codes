# %% [markdown]
# ## Loading HuggingFace dataset

# %% [markdown]
# ### Using pandas (we can use crossiant, polars also)

# %%
# !pip install pyarrow
# !pip install fastparquet
# Out:
# ...
#      ---------------------------------------- 27.5/27.5 MB 7.3 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      -------------------------------------- 669.2/669.2 kB 3.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.7/1.7 MB 6.4 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade pyarrow datasets pandas
# Out:
# ...
#   Using cached datasets-4.6.0-py3-none-any.whl (520 kB)
# ...
#   Using cached multiprocess-0.70.18-py311-none-any.whl (144 kB)
# ...
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_parquet("hf://datasets/chungimungi/Indian-History/data/train-00000-of-00001.parquet")

# %%
df.head()
# Out:
#                                               prompt  \
# 0  Can you tell me about the Mughal Empire?\n\nTh...
# 1  What was the reason behind the sack of Delhi S...
# 2  Which of the great Indian kingdoms that existe...
# 3  What were the main policies of Lord Dalhousie ...
# 4  What is the significance of Mount Kailash, how...
#
#                                           completion  \
# 0  You're off to a great start. The Mughal Empire...
# 1  The sack of Delhi Sultanate by Timur in 1398 A...
# 2  I'll clarify and provide the answer you're loo...
# 3  Lord Dalhousie was the Governor-General of Ind...
# 4  Mount Kailash is a sacred site revered by seve...
#
#                                        system_prompt
# 0  you are a helpful assistant who is an expert o...
# 1  you are a helpful assistant who is an expert o...
# 2  you are a helpful assistant who is an expert o...
# 3  you are a helpful assistant who is an expert o...
# 4  you are a helpful assistant who is an expert o...

# %%
df.dtypes
# Out:
# prompt           str
# completion       str
# system_prompt    str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   prompt         100 non-null    str
#  1   completion     100 non-null    str
#  2   system_prompt  100 non-null    str
# dtypes: str(3)
# memory usage: 299.8 KB

# %% [markdown]
# ### using HF (datasets library : gives many features)

# %%
from datasets import load_dataset

# %%
ds = load_dataset("chungimungi/Indian-History",split="train") # train (means download only that partition of data)
# but here whole data is meant for train only, so it will download whole dataset

# %%
ds
# Out:
# Dataset({
#     features: ['prompt', 'completion', 'system_prompt'],
#     num_rows: 100
# })

# %%
mughal_filter = ds.filter(lambda x : "Mughal" in x["prompt"])
# Out:
# Filter:   0%|          | 0/100 [00:00<?, ? examples/s]

# %%
mughal_filter # same ds type
# Out:
# Dataset({
#     features: ['prompt', 'completion', 'system_prompt'],
#     num_rows: 22
# })

# %%
mughal_filter["prompt"][0]
# Out:
# 'Can you tell me about the Mughal Empire?\n\nThe Mughal Empire was a vast and influential empire that once spanned a large portion of the Indian subcontinent and other parts of South Asia. They had a rich and diverse culture and were patrons of the arts, architecture and had a great legacy of literature. What is the name of the foundation year of the Mughal Empire?\n\nThe Mughal Empire was founded by Babur in 1526.'

# %%
type(mughal_filter)
# Out:
# datasets.arrow_dataset.Dataset

# %%
m_3 = mughal_filter.select(range(3)) # top 3 rows

# %%
m_3["prompt"]
# Out:
# Column(['Can you tell me about the Mughal Empire?\n\nThe Mughal Empire was a vast and influential empire that once spanned a large portion of the Indian subcontinent and other parts of South Asia. They had a rich and diverse culture and were patrons of the arts, architecture and had a great legacy of literature. What is the name of the foundation year of the Mughal Empire?\n\nThe Mughal Empire was founded by Babur in 1526.', "What was the significance of the Battle of Panipat during the Second Mughal Empire's time?\n\nThe Battle of Panipat was a pivotal encounter between the Afghans and the Mughals. It occurred during the Second Mughal Empire's time, with the First Mughal Empire having a significant presence during the events of the First Battle of Panipat in 1526 and the Second Mughal Empire events unfolding in the Second Battle of Panipat during 1556.", "I'm interested in learning about the history of India. I'm particularly interested in the Mughal Empire, and anything related to 
# ...
